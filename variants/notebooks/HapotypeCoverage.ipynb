# %%
import joblib
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Coverage of haplotype assemblies

# %%
data[['sample', 'project']].to_csv("samproj.txt", sep='\t')

# %%
# Output from ../scripts/hap_mapstats.py
data = joblib.load("../data/hap_mapstats.jl")
# Index is the directory, which has structure {project}_{sample}_{haplotag}
sample = pd.Series(data.index, index=data.index).str.split('_', expand=True)
sample.columns = ['project', 'sample', 'haplotag']
data = data.join(sample)

data['appx genome % 1x'] = data["reference bases single covered"] / 3.2e9

# Join with metadata
meta = pd.read_csv("../../metadata/metadata.txt", sep='\t')
meta.set_index('Individual', inplace=True)
data['sex'] = data['sample'].map(meta['Sex'])
data['population'] = data['sample'].map(meta['Superpopulation code'])

# Summarize sizes
col_order = ['Number of deletions in [1000,inf)',
             'Number of deletions in [400,1000)',
             'Number of deletions in [300,400)',
             'Number of deletions in [100,300)',
             'Number of deletions in [50,100)', 
             'Number of deletions in [0,50)',
             'Number of substitutions', 
             'Number of insertions in [0,50)',
             'Number of insertions in [50,100)', 
             'Number of insertions in [100,300)',
             'Number of insertions in [300,400)',
             'Number of insertions in [400,1000)',
             'Number of insertions in [1000,inf)']
new_names = pd.Series([_.split(' ')[-1] for _ in col_order])
new_names[:6] = '-' + new_names[:6]
new_names[6] = "SNV"
name_map = {_[0]:_[1] for _ in zip(col_order, new_names)}
data[">=50bp DEL Total"] = data[col_order[:5]].sum(axis=1)
data["Small Variant Total"] = data[col_order[5:8]].sum(axis=1)
data[">=50bp INS Total"] = data[col_order[8:]].sum(axis=1)

# %%
print(len(data), "haplotypes")
print(len(data.groupby(['sample', 'project']).size()), 'samples')
print(len(data['sample'].unique()) - 1, 'individuals') # HG002 == NA24385 so -1
# Out:
# 172 haplotypes
# 86 samples
# 78 individuals

# %%
replicates = data[data["haplotag"].isin(["H1", "pat"])]['sample'].value_counts()
replicates["NA24385"] += 1
replicates[replicates != 1]
# Out:
# HG00733    3
# NA19240    2
# NA24385    3
# HG03486    2
# HG02818    2
# NA12878    2
# Name: sample, dtype: int64

# %%
view = meta.groupby("Superpopulation name").size().to_frame("Sample Count")
p = sb.barplot(data=view.reset_index(), x="Superpopulation name", y="Sample Count") 
p.set_title("Individual Superpopulation Counts")
hide = plt.xticks(rotation=45, ha='right')

# %%
p = sb.histplot(data=data, x="appx genome % 1x")
p.set(title="Percent of the reference (3.2e9bp) singly covered", ylabel="Haplotype count")
# Out:
# [Text(0.5, 1.0, 'Percent of the reference (3.2e9bp) singly covered'),
#  Text(0, 0.5, 'Haplotype count')]

# %%
p = sb.catplot(data=data, x="sample", y="reference bases single covered", hue='project')
p.set(xticklabels=[], title="Reference bases singly covered", ylabel="Bases", xlabel="Haplotype")

# %% [markdown]
# Technically, giab project is an hprc assembly.
#
# What's up with the 2.70e9 vs 2.82e9?
# Is it a sex difference?

# %%
p = sb.catplot(data=data, x="sample", y="reference bases single covered", hue='sex')
p.set(xticklabels=[], title="Reference bases singly covered", ylabel="Bases", xlabel="Haplotype")

# %% [markdown]
# Ok, so the lower bin is almost exclusively males. But males aren't exclusive to the lower bin..

# %%
data['is_lower_cov'] = data["reference bases single covered"] < 2.72e9
data.groupby(['is_lower_cov', 'sex']).size().unstack()
# Out:
# sex           female  male
# is_lower_cov
# False             95    55
# True               1    19

# %% [markdown]
# Let's check population real quick

# %%
p = sb.catplot(data=data, x="sample", y="reference bases single covered", hue='population')
p.set(xticklabels=[], title="Reference bases singly covered", ylabel="Bases", xlabel="Haplotype")

# %%
# looking at the lower_covered 
data[data["is_lower_cov"]]
# Out:
#                     Number of mapped sequences  Number of primary alignments  \
# hprc_HG005_H1                              997                          1687
# hprc_HG00621_H1                            575                          1212
# hprc_HG00673_H1                            676                          1392
# hprc_HG01106_H1                            653                          1510
# hprc_HG01109_H1                            783                          1552
# hprc_HG01243_H1                            801                          1434
# hprc_HG01258_H1                            595                          1373
# hprc_HG01358_H1                            882                          1607
# hprc_HG01928_H1                            646                          1471
# hprc_HG01952_H1                            663                          1326
# hprc_HG02055_H1                            897                          1753
# hprc_HG02145_H1                           1015                          1785
# hprc_HG02486_H1                            687                          1340
# hprc_HG02572_H1                           1067                          1810
# hprc_HG02717_H1                            843                          1651
# hprc_HG03098_H1                            879                          1740
# hprc_HG03492_H1                            967                          1699
# hprc_HG03579_H1                            932                          1749
# eichler_HG00732_H1                         938                          1015
# giab_HG002_pat                             693                          1668
#
#                     Number of secondary alignments  \
# hprc_HG005_H1                                    0
# hprc_HG00621_H1                                  0
# hprc_HG00673_H1                                  0
# hprc_HG01106_H1                                  0
# hprc_HG01109_H1                                  0
# hprc_HG01243_H1                                  0
# hprc_HG01258_H1                                  0
# hprc_HG01358_H1                                  0
# hprc_HG01928_H1                                  0
# hprc_HG01952_H1                                  0
# hprc_HG02055_H1                                  0
# hprc_HG02145_H1                                  0
# hprc_HG02486_H1                                  0
# hprc_HG02572_H1                                  0
# hprc_HG02717_H1                                  0
# hprc_HG03098_H1                                  0
# hprc_HG03492_H1                                  0
# hprc_HG03579_H1                                  0
# eichler_HG00732_H1                               0
# giab_HG002_pat                                   0
#
#                     Number of primary alignments with >65535 CIGAR operations  \
# hprc_HG005_H1                                                       0
# hprc_HG00621_H1                                                     0
# hprc_HG00673_H1                                                     0
# hprc_HG01106_H1                                                     0
# hprc_HG01109_H1                                                     0
# hprc_HG01243_H1                                                     0
# hprc_HG01258_H1                                                     0
# hprc_HG01358_H1                                                     0
# hprc_HG01928_H1                                                     0
# hprc_HG01952_H1                                                     0
# hprc_HG02055_H1                                                     0
# hprc_HG02145_H1                                                     0
# hprc_HG02486_H1                                                     0
# hprc_HG02572_H1                                                     0
# hprc_HG02717_H1                                                     0
# hprc_HG03098_H1                                                     0
# hprc_HG03492_H1                                                     0
# hprc_HG03579_H1                                                     0
# eichler_HG00732_H1                                                  0
# giab_HG002_pat                                                      0
#
#                     Number of bases in mapped sequences  \
# hprc_HG005_H1                               11067736126
# hprc_HG00621_H1                             10790176931
# hprc_HG00673_H1                              7703990819
# hprc_HG01106_H1                             16694025317
# hprc_HG01109_H1                              9978657048
# hprc_HG01243_H1                             10475675728
# hprc_HG01258_H1                              9863256924
# hprc_HG01358_H1                             15672708864
# hprc_HG01928_H1                             12608706693
# hprc_HG01952_H1                              8064569583
# hprc_HG02055_H1                              9904834014
# hprc_HG02145_H1                              7159517841
# hprc_HG02486_H1                             12744655164
# hprc_HG02572_H1                              6349359188
# hprc_HG02717_H1                              9796454174
# hprc_HG03098_H1                             11370557835
# hprc_HG03492_H1                              5937133882
# hprc_HG03579_H1                              8542815557
# eichler_HG00732_H1                           3749051155
# giab_HG002_pat                              31323274948
#
#                     Number of mapped bases  Number of substitutions  \
# hprc_HG005_H1                   2808852891                  9339259
# hprc_HG00621_H1                 2782442122                  7995243
# hprc_HG00673_H1                 2790103898                  9808089
# hprc_HG01106_H1                 2800766727                  9294469
# hprc_HG01109_H1                 2798527303                 10882661
# hprc_HG01243_H1                 2788673111                  9678460
# hprc_HG01258_H1                 2793359331                 10262081
# hprc_HG01358_H1                 2806303662                  9974078
# hprc_HG01928_H1                 2796848987                 10647793
# hprc_HG01952_H1                 2784374273                  9217817
# hprc_HG02055_H1                 2815480215                 11341136
# hprc_HG02145_H1                 2806709099                 10938774
# hprc_HG02486_H1                 2796431518                  9681652
# hprc_HG02572_H1                 2805548988                 10505060
# hprc_HG02717_H1                 2807209713                 11561399
# hprc_HG03098_H1                 2799619457                 11705820
# hprc_HG03492_H1                 2807461894                 10263021
# hprc_HG03579_H1                 2814341388                 11353335
# eichler_HG00732_H1              2723015046                  6355417
# giab_HG002_pat                  2798645321                 10313068
#
#                     Number of insertions in [0,50)  \
# hprc_HG005_H1                               424563
# hprc_HG00621_H1                             396780
# hprc_HG00673_H1                             403721
# hprc_HG01106_H1                             399186
# hprc_HG01109_H1                             422325
# hprc_HG01243_H1                             422387
# hprc_HG01258_H1                             408772
# hprc_HG01358_H1                             400709
# hprc_HG01928_H1                             406428
# hprc_HG01952_H1                             396149
# hprc_HG02055_H1                             477565
# hprc_HG02145_H1                             464853
# hprc_HG02486_H1                             438007
# hprc_HG02572_H1                             468049
# hprc_HG02717_H1                             442481
# hprc_HG03098_H1                             462496
# hprc_HG03492_H1                             420519
# hprc_HG03579_H1                             451685
# eichler_HG00732_H1                          536053
# giab_HG002_pat                              396151
#
#                     Number of insertions in [50,100)  \
# hprc_HG005_H1                                   3900
# hprc_HG00621_H1                                 3660
# hprc_HG00673_H1                                 3571
# hprc_HG01106_H1                                 3703
# hprc_HG01109_H1                                 4027
# hprc_HG01243_H1                                 3877
# hprc_HG01258_H1                                 3720
# hprc_HG01358_H1                                 3915
# hprc_HG01928_H1                                 3819
# hprc_HG01952_H1                                 3555
# hprc_HG02055_H1                                 4494
# hprc_HG02145_H1                                 4126
# hprc_HG02486_H1                                 3873
# hprc_HG02572_H1                                 4196
# hprc_HG02717_H1                                 4098
# hprc_HG03098_H1                                 4226
# hprc_HG03492_H1                                 3837
# hprc_HG03579_H1                                 4640
# eichler_HG00732_H1                              3062
# giab_HG002_pat                                  3920
#
#                     Number of insertions in [100,300)  ...  project   sample  \
# hprc_HG005_H1                                    4985  ...     hprc    HG005
# hprc_HG00621_H1                                  4478  ...     hprc  HG00621
# hprc_HG00673_H1                                  4690  ...     hprc  HG00673
# hprc_HG01106_H1                                  4671  ...     hprc  HG01106
# hprc_HG01109_H1                                  4898  ...     hprc  HG01109
# hprc_HG01243_H1                                  4981  ...     hprc  HG01243
# hprc_HG01258_H1                                  4720  ...     hprc  HG01258
# hprc_HG01358_H1                                  5174  ...     hprc  HG01358
# hprc_HG01928_H1                                  4722  ...     hprc  HG01928
# hprc_HG01952_H1                                  4640  ...     hprc  HG01952
# hprc_HG02055_H1                                  5898  ...     hprc  HG02055
# hprc_HG02145_H1                                  5390  ...     hprc  HG02145
# hprc_HG02486_H1                                  4747  ...     hprc  HG02486
# hprc_HG02572_H1                                  5204  ...     hprc  HG02572
# hprc_HG02717_H1                                  5461  ...     hprc  HG02717
# hprc_HG03098_H1                                  5220  ...     hprc  HG03098
# hprc_HG03492_H1                                  5115  ...     hprc  HG03492
# hprc_HG03579_H1                                  5598  ...     hprc  HG03579
# eichler_HG00732_H1                               3305  ...  eichler  HG00732
# giab_HG002_pat                                   4818  ...     giab    HG002
#
#                     haplotag  appx genome % 1x     sex  population  \
# hprc_HG005_H1             H1          0.841742    male         EAS
# hprc_HG00621_H1           H1          0.843388    male         EAS
# hprc_HG00673_H1           H1          0.841891    male         EAS
# hprc_HG01106_H1           H1          0.842734    male         AMR
# hprc_HG01109_H1           H1          0.843391    male         AMR
# hprc_HG01243_H1           H1          0.842215    male         AMR
# hprc_HG01258_H1           H1          0.842404    male         AMR
# hprc_HG01358_H1           H1          0.842386    male         AMR
# hprc_HG01928_H1           H1          0.843009    male         AMR
# hprc_HG01952_H1           H1          0.843346    male         AMR
# hprc_HG02055_H1           H1          0.841278    male         AFR
# hprc_HG02145_H1           H1          0.842640    male         AFR
# hprc_HG02486_H1           H1          0.841178    male         AFR
# hprc_HG02572_H1           H1          0.839538    male         AFR
# hprc_HG02717_H1           H1          0.842306    male         AFR
# hprc_HG03098_H1           H1          0.840925    male         AFR
# hprc_HG03492_H1           H1          0.842411    male         SAS
# hprc_HG03579_H1           H1          0.840331    male         AFR
# eichler_HG00732_H1        H1          0.839963  female         AMR
# giab_HG002_pat           pat          0.844036    male         EUR
#
#                     >=50bp DEL Total  Small Variant Total  >=50bp INS Total  \
# hprc_HG005_H1                   8474             10150040             18682
# hprc_HG00621_H1                 7755              8761462             16505
# hprc_HG00673_H1                 8285             10599281             16090
# hprc_HG01106_H1                 8227             10076146             17330
# hprc_HG01109_H1                 8788             11700158             18201
# hprc_HG01243_H1                 8738             10505817             18758
# hprc_HG01258_H1                 8417             11051237             17529
# hprc_HG01358_H1                 8154             10758435             20148
# hprc_HG01928_H1                 8638             11444129             17334
# hprc_HG01952_H1                 8087              9993767             15728
# hprc_HG02055_H1                 9791             12255571             22445
# hprc_HG02145_H1                 9471             11826284             21277
# hprc_HG02486_H1                 9010             10545657             16287
# hprc_HG02572_H1                 9596             11409904             19116
# hprc_HG02717_H1                 9563             12445303             20191
# hprc_HG03098_H1                 9444             12605980             20680
# hprc_HG03492_H1                 8647             11071703             19590
# hprc_HG03579_H1                 9307             12244994             21720
# eichler_HG00732_H1              6884              7230463             11055
# giab_HG002_pat                  8303             11102784             18662
#
#                     is_lower_cov
# hprc_HG005_H1               True
# hprc_HG00621_H1             True
# hprc_HG00673_H1             True
# hprc_HG01106_H1             True
# hprc_HG01109_H1             True
# hprc_HG01243_H1             True
# hprc_HG01258_H1             True
# hprc_HG01358_H1             True
# hprc_HG01928_H1             True
# hprc_HG01952_H1             True
# hprc_HG02055_H1             True
# hprc_HG02145_H1             True
# hprc_HG02486_H1             True
# hprc_HG02572_H1             True
# hprc_HG02717_H1             True
# hprc_HG03098_H1             True
# hprc_HG03492_H1             True
# hprc_HG03579_H1             True
# eichler_HG00732_H1          True
# giab_HG002_pat              True
#
# [20 rows x 32 columns]

# %%
# There's a pattern in haplotag?
p = sb.catplot(data=data, x="sample", y="reference bases single covered", hue='haplotag')
p.set(xticklabels=[], title="Reference bases singly covered", ylabel="Bases", xlabel="Haplotype")

# %% [markdown]
# The one female in the lower bin is an eichler assembly. I have previously seen evidence that the parental haplotype assignment of contigs in the eichler/li assemblies aren't perfect. So it's possible some of the `eichler_HG00732_H1` assembly actually belongs in `eichler_HG00732_H2`. That's reasonable to consider but still doesn't explain the pattern.

# %%
data[data['is_lower_cov'] & (data['sex'] == 'female')][['project', 'sample']]
# Out:
#                     project   sample
# eichler_HG00732_H1  eichler  HG00732

# %% [markdown]
# What if the regions not covered singly are covered multiple-ly!?

# %%
p = sb.catplot(data=data, x="sample", y="reference bases multi covered", hue='is_lower_cov')
p.set(xticklabels=[], title="Reference bases multi covered", ylabel="Bases", xlabel="Haplotype")

# %% [markdown]
# I think I'm just seeing assemblies cluster by project

# %%
p = sb.catplot(data=data, x="sample", y="reference bases multi covered", hue='project')
p.set(xticklabels=[], title="Reference bases multi covered", ylabel="Bases", xlabel="Haplotype")

# %% [markdown]
# Check uncovered, too

# %%
p = sb.catplot(data=data, x="sample", y="reference bases uncovered", hue='is_lower_cov')
p.set(xticklabels=[], title="Reference bases uncovered", ylabel="Bases", xlabel="Haplotype")

# %% [markdown]
# This leads me to believe there's big deletions or something. I have to go back to the bed files to figure out if the uncovered regions are shared. See `chrYExplore.ipynb`.
#
# My hypothesis is that some of these uncovered regions from males' H1 are large chrY DELs. If this is the case, we might be able to pull out alignments from those regions, see if they're split, and use that to build a 'large DEL' caller to complement paftools.jl

# %% [markdown]
# # Variant calling stats

# %%
p = sb.histplot(data=data, x="Number of mapped sequences", hue="project", multiple='dodge')
p.set(title="Mapped sequences per-haplotype assembly", ylabel="Haplotype Count")
# Out:
# [Text(0.5, 1.0, 'Mapped sequences per-haplotype assembly'),
#  Text(0, 0.5, 'Haplotype Count')]

# %%
p = sb.histplot(data=data, x="Number of mapped bases", hue="project", multiple='dodge', binwidth=1e8)
p.set(title="Mapped bases per-haplotype assembly", ylabel="Haplotype Count")
# Out:
# [Text(0.5, 1.0, 'Mapped bases per-haplotype assembly'),
#  Text(0, 0.5, 'Haplotype Count')]

# %%
szbin_view1 = data.melt(id_vars=['project','sample', 'haplotag', 'population'], 
                 value_vars=col_order, var_name='SizeBin', value_name='count')
szbin_view1['SizeBin'] = szbin_view1["SizeBin"].map(name_map)

# %%
p = sb.boxplot(data=szbin_view1[szbin_view1["SizeBin"].isin(new_names[5:8])], x="SizeBin", y="count", hue='project')
p.set(title="Small Variant Counts", ylabel="Count (log)", yscale='log')
sb.move_legend(p, "upper left", bbox_to_anchor=(1,1), frameon=False)
hide = plt.xticks(rotation=45, ha='right')

# %%
p = sb.boxplot(data=szbin_view1[szbin_view1["SizeBin"].isin(new_names[5:8])], x="SizeBin", y="count", hue='population')
p.set(title="Small Variant Counts", ylabel="Count (log)", yscale='log')
sb.move_legend(p, "upper left", bbox_to_anchor=(1,1), frameon=False)
hide = plt.xticks(rotation=45, ha='right')

# %%
p = sb.boxplot(data=szbin_view1[~szbin_view1["SizeBin"].isin(new_names[5:8])], x="SizeBin", y="count", hue='project')
p.set(title="Large Variant Counts")
sb.move_legend(p, "upper left", bbox_to_anchor=(1,1), frameon=False)
hide = plt.xticks(rotation=45, ha='right')

# %%
p = sb.boxplot(data=szbin_view1[~szbin_view1["SizeBin"].isin(new_names[5:8])], x="SizeBin", y="count", hue='population')
p.set(title="Large Variant Counts")
sb.move_legend(p, "upper left", bbox_to_anchor=(1,1), frameon=False)
hide = plt.xticks(rotation=45, ha='right')

# %%
big_bin_cols = [">=50bp DEL Total", "Small Variant Total", ">=50bp INS Total"]

# %%
szbin_view2 = data.melt(id_vars=['project','sample', 'haplotag', 'population', 'sex'], 
                 value_vars=big_bin_cols, var_name='SizeBin', value_name='count')

# %%
p = sb.boxplot(data=szbin_view2[szbin_view2["SizeBin"] == "Small Variant Total"], x="SizeBin", y="count", hue='project')
sb.move_legend(p, "upper left", bbox_to_anchor=(1,1), frameon=False)
p.set(title="Small Variants (-50bp,50bp)")
# Out:
# [Text(0.5, 1.0, 'Small Variants (-50bp,50bp)')]

# %%
p = sb.boxplot(data=szbin_view2[szbin_view2["SizeBin"] == "Small Variant Total"], x="SizeBin", y="count", hue='population')
sb.move_legend(p, "upper left", bbox_to_anchor=(1,1), frameon=False)
p.set(title="Small Variants (-50bp,50bp)")
# Out:
# [Text(0.5, 1.0, 'Small Variants (-50bp,50bp)')]

# %%
p = sb.boxplot(data=szbin_view2[szbin_view2["SizeBin"] != "Small Variant Total"], x="SizeBin", y="count", hue='project')
sb.move_legend(p, "upper left", bbox_to_anchor=(1,1), frameon=False)
p.set(title="Large Variants")
# Out:
# [Text(0.5, 1.0, 'Large Variants')]

# %%
p = sb.boxplot(data=szbin_view2[szbin_view2["SizeBin"] != "Small Variant Total"], x="SizeBin", y="count", hue='population')
sb.move_legend(p, "upper left", bbox_to_anchor=(1,1), frameon=False)
p.set(title="Large Variants")
# Out:
# [Text(0.5, 1.0, 'Large Variants')]

# %%
p = sb.boxplot(data=szbin_view2[szbin_view2["SizeBin"] != "Small Variant Total"], x="SizeBin", y="count", hue='sex')
sb.move_legend(p, "upper left", bbox_to_anchor=(1,1), frameon=False)
p.set(title="Large Variants")
# Out:
# [Text(0.5, 1.0, 'Large Variants')]
